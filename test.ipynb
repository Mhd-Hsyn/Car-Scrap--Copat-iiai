# %%
html= """

<span _ngcontent-alg-c125="" class="list-group"><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/select?displayStr=Copart Select&amp;from=/vehicleFinder" title="Copart Select"> Copart Select </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(456)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/electricvehicles?displayStr=Electric Vehicles&amp;from=/vehicleFinder" title="Electric Vehicles"> Electric Vehicles </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(4333)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/hotitems?displayStr=Hot Items&amp;from=/vehicleFinder" title="Hot Items"> Hot Items </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(49463)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/fleetlease?displayStr=Fleet / Lease&amp;from=/vehicleFinder" title="Fleet / Lease"> Fleet / Lease </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(1080)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/hybridvehicles?displayStr=Hybrid Vehicles&amp;from=/vehicleFinder" title="Hybrid Vehicles"> Hybrid Vehicles </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(11947)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/classics?displayStr=Classics&amp;from=/vehicleFinder" title="Classics"> Classics </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(5003)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/exotics?displayStr=Exotics&amp;from=/vehicleFinder" title="Exotics"> Exotics </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(1629)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/nolicenserequired?displayStr=No License Required&amp;from=/vehicleFinder" title="No License Required"> No License Required </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(74626)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/buyitnow?displayStr=Buy It Now&amp;from=/vehicleFinder" title="Buy It Now"> Buy It Now </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(19743)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/runanddrive?displayStr=Run and Drive&amp;from=/vehicleFinder" title="Run and Drive"> Run and Drive </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(228627)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/puresaleitems?displayStr=Pure Sale&amp;from=/vehicleFinder" title="Pure Sale"> Pure Sale </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(292823)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/newitems?displayStr=New Items&amp;from=/vehicleFinder" title="New Items"> New Items </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(80637)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/featuredvehicles?displayStr=Featured Vehicles&amp;from=/vehicleFinder" title="Featured Vehicles"> Featured Vehicles </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(231)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/offsitesales?displayStr=Offsite Sales&amp;from=/vehicleFinder" title="Offsite Sales"> Offsite Sales </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(2939)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/recoveredthefts?displayStr=Recovered Thefts&amp;from=/vehicleFinder" title="Recovered Thefts"> Recovered Thefts </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(13738)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/rentals?displayStr=Rentals&amp;from=/vehicleFinder" title="Rentals"> Rentals </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(1679)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/copartgo?displayStr=Public and General Business&amp;from=/vehicleFinder" title="Public and General Business"> Public and General ... </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(1916)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/bakrepossessed?displayStr=Bank / Repossessed&amp;from=/vehicleFinder" title="Bank / Repossessed"> Bank / Repossessed </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(2855)</span><!-- --></span></span><span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/specialtyvehicles?displayStr=Specialty Vehicles&amp;from=/vehicleFinder" title="Specialty Vehicles"> Specialty Vehicles </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(13056)</span><!-- --></span></span><!-- --></span>


"""

# %%
import json
from bs4 import BeautifulSoup



def extract_categories(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    target_span = soup.find('span', class_='list-group')
    if target_span:
        all_child_spans = target_span.find_all('span', class_='ng-star-inserted')
        base_url = "https://www.copart.com/"
        category = {}
        for span in all_child_spans:
            print("\n\n", span)
            a_tag= span.find('a')
            url= a_tag.get('href', None) if a_tag else None
            title= a_tag.get('title', None) if a_tag else None
            if url is not None and title is not None:
                category[title] = base_url+url
            
        print(json.dumps(category, indent= 2))
    
categories = extract_categories(html)
print(json.dumps(categories, indent=4))
# Out:
#  <span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/select?displayStr=Copart Select&amp;from=/vehicleFinder" title="Copart Select"> Copart Select </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(456)</span><!-- --></span></span>
#
#
#  <span _ngcontent-alg-c125="" class="counts ng-star-inserted">(456)</span>
#
#
#  <span _ngcontent-alg-c125="" class="ng-star-inserted"><span _ngcontent-alg-c125="" class="list-group-item"><a _ngcontent-alg-c125="" aria-labelledby="quickPicksTab_0" class="bold ng-star-inserted" href="vehicle-search-featured/electricvehicles?displayStr=Electric Vehicles&amp;from=/vehicleFinder" title="Electric Vehicles"> Electric Vehicles </a><!-- --><span _ngcontent-alg-c125="" class="counts ng-star-inserted">(4333)</span><!-- --></span></span>
#
#
# ...

# %%
data = {
    "Vehicle_Findby": [
        {
            "Featured_Items": [
                {
                    "Copart_Select": "https://www.copart.com/vehicle-search-featured/select?displayStr=Copart Select&from=/vehicleFinder",
                    "Electric_Vehicles": "https://www.copart.com/vehicle-search-featured/electricvehicles?displayStr=Electric Vehicles&from=/vehicleFinder",
                    "Hot_Items": "https://www.copart.com/vehicle-search-featured/hotitems?displayStr=Hot Items&from=/vehicleFinder",
                    "Fleet_/_Lease": "https://www.copart.com/vehicle-search-featured/fleetlease?displayStr=Fleet / Lease&from=/vehicleFinder",
                    "Hybrid_Vehicles": "https://www.copart.com/vehicle-search-featured/hybridvehicles?displayStr=Hybrid Vehicles&from=/vehicleFinder",
                    "Classics": "https://www.copart.com/vehicle-search-featured/classics?displayStr=Classics&from=/vehicleFinder",
                    "Exotics": "https://www.copart.com/vehicle-search-featured/exotics?displayStr=Exotics&from=/vehicleFinder",
                    "No_License_Required": "https://www.copart.com/vehicle-search-featured/nolicenserequired?displayStr=No License Required&from=/vehicleFinder",
                    "Buy_It_Now": "https://www.copart.com/vehicle-search-featured/buyitnow?displayStr=Buy It Now&from=/vehicleFinder",
                    "Run_and_Drive": "https://www.copart.com/vehicle-search-featured/runanddrive?displayStr=Run and Drive&from=/vehicleFinder",
                    "Pure_Sale": "https://www.copart.com/vehicle-search-featured/puresaleitems?displayStr=Pure Sale&from=/vehicleFinder",
                    "New_Items": "https://www.copart.com/vehicle-search-featured/newitems?displayStr=New Items&from=/vehicleFinder",
                    "Featured_Vehicles": "https://www.copart.com/vehicle-search-featured/featuredvehicles?displayStr=Featured Vehicles&from=/vehicleFinder",
                    "Offsite_Sales": "https://www.copart.com/vehicle-search-featured/offsitesales?displayStr=Offsite Sales&from=/vehicleFinder",
                    "Recovered_Thefts": "https://www.copart.com/vehicle-search-featured/recoveredthefts?displayStr=Recovered Thefts&from=/vehicleFinder",
                    "Rentals": "https://www.copart.com/vehicle-search-featured/rentals?displayStr=Rentals&from=/vehicleFinder",
                    "Public_and_General_Business": "https://www.copart.com/vehicle-search-featured/copartgo?displayStr=Public and General Business&from=/vehicleFinder",
                    "Bank_/_Repossessed": "https://www.copart.com/vehicle-search-featured/bakrepossessed?displayStr=Bank / Repossessed&from=/vehicleFinder",
                    "Specialty_Vehicles": "https://www.copart.com/vehicle-search-featured/specialtyvehicles?displayStr=Specialty Vehicles&from=/vehicleFinder"
                }
            ],
            "Vehicle_Types": [
                {
                    "ATVs": "https://www.copart.com/vehicle-search-type/atvs?displayStr=ATVs&from=/vehicleFinder",
                    "Agriculture_and_Farm_equipment": "https://www.copart.com/vehicle-search-type/agricultureandfarmequipment?displayStr=Agriculture and Farm equipment&from=/vehicleFinder",
                    "Automobiles": "https://www.copart.com/vehicle-search-type/automobiles?displayStr=Automobiles&from=/vehicleFinder",
                    "Boats": "https://www.copart.com/vehicle-search-type/boats?displayStr=Boats&from=/vehicleFinder",
                    "Bus": "https://www.copart.com/vehicle-search-type/bus?displayStr=Bus&from=/vehicleFinder",
                    "Construction_equipment": "https://www.copart.com/vehicle-search-type/constructionequipment?displayStr=Construction equipment&from=/vehicleFinder",
                    "Dirt_Bikes": "https://www.copart.com/vehicle-search-type/dirtbikes?displayStr=Dirt Bikes&from=/vehicleFinder",
                    "Forklifts": "https://www.copart.com/vehicle-search-type/forklifts?displayStr=Forklifts&from=/vehicleFinder",
                    "Heavy_Duty_Trucks": "https://www.copart.com/vehicle-search-type/heavydutytrucks?displayStr=Heavy Duty Trucks&from=/vehicleFinder",
                    "Industrial_Equipment": "https://www.copart.com/vehicle-search-type/industrialequipment?displayStr=Industrial Equipment&from=/vehicleFinder",
                    "Jet_Skis": "https://www.copart.com/vehicle-search-type/jetskis?displayStr=Jet Skis&from=/vehicleFinder",
                    "Medium_Duty_/_Box_Trucks": "https://www.copart.com/vehicle-search-type/mediumdutyboxtrucks?displayStr=Medium Duty / Box Trucks&from=/vehicleFinder",
                    "Motorcycles": "https://www.copart.com/vehicle-search-type/motorcycles?displayStr=Motorcycles&from=/vehicleFinder",
                    "Pickup_Trucks": "https://www.copart.com/vehicle-search-type/pickuptrucks?displayStr=Pickup Trucks&from=/vehicleFinder",
                    "RVs": "https://www.copart.com/vehicle-search-type/recreationalvehicles?displayStr=RVs&from=/vehicleFinder",
                    "Snowmobiles": "https://www.copart.com/vehicle-search-type/snowmobiles?displayStr=Snowmobiles&from=/vehicleFinder",
                    "Trailers": "https://www.copart.com/vehicle-search-type/trailers?displayStr=Trailers&from=/vehicleFinder"
                }
            ],
            "Makes": [
                {
                    "Acura": "https://www.copart.com/vehicle-search-make/acura?displayStr=Acura&from=/vehicleFinder",
                    "Audi": "https://www.copart.com/vehicle-search-make/audi?displayStr=Audi&from=/vehicleFinder",
                    "BMW": "https://www.copart.com/vehicle-search-make/bmw?displayStr=BMW&from=/vehicleFinder",
                    "Bentley": "https://www.copart.com/vehicle-search-make/bentley?displayStr=Bentley&from=/vehicleFinder",
                    "Buick": "https://www.copart.com/vehicle-search-make/buick?displayStr=Buick&from=/vehicleFinder",
                    "Cadillac": "https://www.copart.com/vehicle-search-make/cadillac?displayStr=Cadillac&from=/vehicleFinder",
                    "Chevrolet": "https://www.copart.com/vehicle-search-make/chevrolet?displayStr=Chevrolet&from=/vehicleFinder",
                    "Chrysler": "https://www.copart.com/vehicle-search-make/chrysler?displayStr=Chrysler&from=/vehicleFinder",
                    "Datsun": "https://www.copart.com/vehicle-search-make/datsun?displayStr=Datsun&from=/vehicleFinder",
                    "Dodge": "https://www.copart.com/vehicle-search-make/dodge?displayStr=Dodge&from=/vehicleFinder",
                    "Ducati": "https://www.copart.com/vehicle-search-make/ducati?displayStr=Ducati&from=/vehicleFinder",
                    "Ferrari": "https://www.copart.com/vehicle-search-make/ferrari?displayStr=Ferrari&from=/vehicleFinder",
                    "Fiat": "https://www.copart.com/vehicle-search-make/fiat?displayStr=Fiat&from=/vehicleFinder",
                    "Ford": "https://www.copart.com/vehicle-search-make/ford?displayStr=Ford&from=/vehicleFinder",
                    "Freightliner": "https://www.copart.com/vehicle-search-make/freightliner?displayStr=Freightliner&from=/vehicleFinder",
                    "GMC": "https://www.copart.com/vehicle-search-make/gmc?displayStr=GMC&from=/vehicleFinder",
                    "Genesis": "https://www.copart.com/vehicle-search-make/genesis?displayStr=Genesis&from=/vehicleFinder",
                    "Harley": "https://www.copart.com/vehicle-search-make/harley?displayStr=Harley&from=/vehicleFinder",
                    "Hino": "https://www.copart.com/vehicle-search-make/hino?displayStr=Hino&from=/vehicleFinder",
                    "Honda": "https://www.copart.com/vehicle-search-make/honda?displayStr=Honda&from=/vehicleFinder",
                    "Hummer": "https://www.copart.com/vehicle-search-make/hummer?displayStr=Hummer&from=/vehicleFinder",
                    "Hyundai": "https://www.copart.com/vehicle-search-make/hyundai?displayStr=Hyundai&from=/vehicleFinder",
                    "Infiniti": "https://www.copart.com/vehicle-search-make/infiniti?displayStr=Infiniti&from=/vehicleFinder",
                    "International": "https://www.copart.com/vehicle-search-make/international?displayStr=International&from=/vehicleFinder",
                    "Isuzu": "https://www.copart.com/vehicle-search-make/isuzu?displayStr=Isuzu&from=/vehicleFinder",
                    "Jaguar": "https://www.copart.com/vehicle-search-make/jaguar?displayStr=Jaguar&from=/vehicleFinder",
                    "Jeep": "https://www.copart.com/vehicle-search-make/jeep?displayStr=Jeep&from=/vehicleFinder",
                    "Kawasaki": "https://www.copart.com/vehicle-search-make/kawasaki?displayStr=Kawasaki&from=/vehicleFinder",
                    "Kia": "https://www.copart.com/vehicle-search-make/kia?displayStr=Kia&from=/vehicleFinder",
                    "Lamborghini": "https://www.copart.com/vehicle-search-make/lamborghini?displayStr=Lamborghini&from=/vehicleFinder",
                    "Land_Rover": "https://www.copart.com/vehicle-search-make/landrover?displayStr=Land Rover&from=/vehicleFinder",
                    "Lexus": "https://www.copart.com/vehicle-search-make/lexus?displayStr=Lexus&from=/vehicleFinder",
                    "Lincoln": "https://www.copart.com/vehicle-search-make/lincoln?displayStr=Lincoln&from=/vehicleFinder",
                    "Lotus": "https://www.copart.com/vehicle-search-make/lotus?displayStr=Lotus&from=/vehicleFinder",
                    "Mack": "https://www.copart.com/vehicle-search-make/mack?displayStr=Mack&from=/vehicleFinder",
                    "Maserati": "https://www.copart.com/vehicle-search-make/maserati?displayStr=Maserati&from=/vehicleFinder",
                    "Mazda": "https://www.copart.com/vehicle-search-make/mazda?displayStr=Mazda&from=/vehicleFinder",
                    "Mclaren": "https://www.copart.com/vehicle-search-make/mclarenautomotive?displayStr=Mclaren&from=/vehicleFinder",
                    "Mercedes-Benz": "https://www.copart.com/vehicle-search-make/mercedesbenz?displayStr=Mercedes-Benz&from=/vehicleFinder",
                    "Mercury": "https://www.copart.com/vehicle-search-make/mercury?displayStr=Mercury&from=/vehicleFinder",
                    "Mini": "https://www.copart.com/vehicle-search-make/mini?displayStr=Mini&from=/vehicleFinder",
                    "Mitsubishi": "https://www.copart.com/vehicle-search-make/mitsubishi?displayStr=Mitsubishi&from=/vehicleFinder",
                    "Nissan": "https://www.copart.com/vehicle-search-make/nissan?displayStr=Nissan&from=/vehicleFinder",
                    "Oldsmobile": "https://www.copart.com/vehicle-search-make/oldsmobile?displayStr=Oldsmobile&from=/vehicleFinder",
                    "Plymouth": "https://www.copart.com/vehicle-search-make/plymouth?displayStr=Plymouth&from=/vehicleFinder",
                    "Polaris": "https://www.copart.com/vehicle-search-make/polaris?displayStr=Polaris&from=/vehicleFinder",
                    "Pontiac": "https://www.copart.com/vehicle-search-make/pontiac?displayStr=Pontiac&from=/vehicleFinder",
                    "Porsche": "https://www.copart.com/vehicle-search-make/porsche?displayStr=Porsche&from=/vehicleFinder",
                    "Ram": "https://www.copart.com/vehicle-search-make/ram?displayStr=Ram&from=/vehicleFinder",
                    "Rolls-Royce": "https://www.copart.com/vehicle-search-make/rollsroyce?displayStr=Rolls-Royce&from=/vehicleFinder",
                    "Saab": "https://www.copart.com/vehicle-search-make/saab?displayStr=Saab&from=/vehicleFinder",
                    "Saturn": "https://www.copart.com/vehicle-search-make/saturn?displayStr=Saturn&from=/vehicleFinder",
                    "Scion": "https://www.copart.com/vehicle-search-make/scion?displayStr=Scion&from=/vehicleFinder",
                    "Smart": "https://www.copart.com/vehicle-search-make/smart?displayStr=Smart&from=/vehicleFinder",
                    "Subaru": "https://www.copart.com/vehicle-search-make/subaru?displayStr=Subaru&from=/vehicleFinder",
                    "Suzuki": "https://www.copart.com/vehicle-search-make/suzuki?displayStr=Suzuki&from=/vehicleFinder",
                    "Tesla": "https://www.copart.com/vehicle-search-make/tesla?displayStr=Tesla&from=/vehicleFinder",
                    "Toyota": "https://www.copart.com/vehicle-search-make/toyota?displayStr=Toyota&from=/vehicleFinder",
                    "Vespa": "https://www.copart.com/vehicle-search-make/vespa?displayStr=Vespa&from=/vehicleFinder",
                    "Volkswagen": "https://www.copart.com/vehicle-search-make/volkswagen?displayStr=Volkswagen&from=/vehicleFinder",
                    "Volvo": "https://www.copart.com/vehicle-search-make/volvo?displayStr=Volvo&from=/vehicleFinder",
                    "Winnebago": "https://www.copart.com/vehicle-search-make/winnebago?displayStr=Winnebago&from=/vehicleFinder",
                    "Yamaha": "https://www.copart.com/vehicle-search-make/yamaha?displayStr=Yamaha&from=/vehicleFinder"
                }
            ],
            "Damage": [
                {
                    "All_Over": "https://www.copart.com/vehicle-search-damage/allover?displayStr=All Over&from=/vehicleFinder",
                    "Biohazardous/Chemical": "https://www.copart.com/vehicle-search-damage/biohazardouschemical?displayStr=Biohazardous/Chemical&from=/vehicleFinder",
                    "Burn": "https://www.copart.com/vehicle-search-damage/burn?displayStr=Burn&from=/vehicleFinder",
                    "Burn_-_Engine": "https://www.copart.com/vehicle-search-damage/burnengine?displayStr=Burn - Engine&from=/vehicleFinder",
                    "Burn_-_Interior": "https://www.copart.com/vehicle-search-damage/burninterior?displayStr=Burn - Interior&from=/vehicleFinder",
                    "Damage_History": "https://www.copart.com/vehicle-search-damage/damagehistory?displayStr=Damage History&from=/vehicleFinder",
                    "Frame_Damage": "https://www.copart.com/vehicle-search-damage/framedamage?displayStr=Frame Damage&from=/vehicleFinder",
                    "Front_End": "https://www.copart.com/vehicle-search-damage/frontend?displayStr=Front End&from=/vehicleFinder",
                    "Hail": "https://www.copart.com/vehicle-search-damage/haildamage?displayStr=Hail&from=/vehicleFinder",
                    "Mechanical": "https://www.copart.com/vehicle-search-damage/mechanical?displayStr=Mechanical&from=/vehicleFinder",
                    "Minor_Dents/Scratches": "https://www.copart.com/vehicle-search-damage/minordentsscratches?displayStr=Minor Dents/Scratches&from=/vehicleFinder",
                    "Normal_Wear": "https://www.copart.com/vehicle-search-damage/normalwear?displayStr=Normal Wear&from=/vehicleFinder",
                    "Partial/Incomplete_Repair": "https://www.copart.com/vehicle-search-damage/partialincompleterepair?displayStr=Partial/Incomplete Repair&from=/vehicleFinder",
                    "Rear_End": "https://www.copart.com/vehicle-search-damage/rearend?displayStr=Rear End&from=/vehicleFinder",
                    "Rollover": "https://www.copart.com/vehicle-search-damage/rollover?displayStr=Rollover&from=/vehicleFinder",
                    "Side": "https://www.copart.com/vehicle-search-damage/side?displayStr=Side&from=/vehicleFinder",
                    "Stripped": "https://www.copart.com/vehicle-search-damage/stripped?displayStr=Stripped&from=/vehicleFinder",
                    "Top/Roof": "https://www.copart.com/vehicle-search-damage/toproof?displayStr=Top/Roof&from=/vehicleFinder",
                    "Undercarriage": "https://www.copart.com/vehicle-search-damage/undercarriage?displayStr=Undercarriage&from=/vehicleFinder",
                    "Vandalism": "https://www.copart.com/vehicle-search-damage/vandalism?displayStr=Vandalism&from=/vehicleFinder",
                    "Water/Flood": "https://www.copart.com/vehicle-search-damage/waterflood?displayStr=Water/Flood&from=/vehicleFinder"
                }
            ],
            "Title_Type": [
                {
                    "Clean_Title": "https://www.copart.com/vehicle-search-title/cleantitle?displayStr=Clean Title&from=/vehicleFinder",
                    "Non-repairable": "https://www.copart.com/vehicle-search-title/nonrepairable?displayStr=Non-repairable&from=/vehicleFinder",
                    "Salvage_Title": "https://www.copart.com/vehicle-search-title/salvagetitle?displayStr=Salvage Title&from=/vehicleFinder"
                }
            ]
        }
    ]
}

# %%
for category in data["Vehicle_Findby"][0]:
    print(f"Category: {category}")
    category_urls = data["Vehicle_Findby"][0][category]
    
    # Loop through each URL in the category
    for url_name, url in category_urls[0].items():
        print(f"Opening URL: {url_name}")
        # Here you can perform actions to open the URL using Selenium or any other web automation tool
        # For demonstration purposes, we'll just print the URL
        print(f"URL: {url}")
# Out:
# Category: Featured_Items
# Opening URL: Copart_Select
# URL: https://www.copart.com/vehicle-search-featured/select?displayStr=Copart Select&from=/vehicleFinder
# Opening URL: Electric_Vehicles
# URL: https://www.copart.com/vehicle-search-featured/electricvehicles?displayStr=Electric Vehicles&from=/vehicleFinder
# Opening URL: Hot_Items
# URL: https://www.copart.com/vehicle-search-featured/hotitems?displayStr=Hot Items&from=/vehicleFinder
# Opening URL: Fleet_/_Lease
# URL: https://www.copart.com/vehicle-search-featured/fleetlease?displayStr=Fleet / Lease&from=/vehicleFinder
# Opening URL: Hybrid_Vehicles
# URL: https://www.copart.com/vehicle-search-featured/hybridvehicles?displayStr=Hybrid Vehicles&from=/vehicleFinder
# Opening URL: Classics
# URL: https://www.copart.com/vehicle-search-featured/classics?displayStr=Classics&from=/vehicleFinder
# Opening URL: Exotics
# URL: https://www.copart.com/vehicle-search-featured/exotics?displayStr=Exotics&from=/vehicleFinder
# ...
